# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from jet_merger import select_and_sort_jet_data
# %matplotlib inline

# %% [markdown]
# ### Importing the data
#
# We are using the Electron Region data.

# %%
event_data = pd.read_csv("output_data/Event_one_Electron.csv") # Electron Region Event one

# %%
# View the merged data head
event_data.head()
# Out:
#    event  eta  phi        et  position  electron  tau
# 0      1    0    0   7.23932         3         0    0
# 1      1    0    1  14.78990         6         0    1
# 2      1    0    2   8.17547         4         0    1
# 3      1    0    3   6.89318         2         0    0
# 4      1    0    4   9.89150         7         0    0

# %% [markdown]
# **Data Dictionary**
#
# - event: Event number (Integer)
# - eta: Index of eta coordinate 0-13 (Integer)
# - phi: Index of phi coordinate, 0-17, which is also specifies the optical link (Integer)
# - et: Transverse energy deposited in the region (Float)
# - position: Position of the cluster within the region, a 4-bit number (Integer)
# - electron: Electron bit signifying that the region likely has an electron or photon deposit (Bool)
# - tau: Tau bit signifying that the region likely has a tau deposit (Bool)

# %%
# Check the shape of the merged dataframe
event_data.shape
# Out:
# (252, 7)

# %% [markdown]
# - The following function will now get the value of Energy (ET) in all 4 regions of the 2x2 submatrix and sum them.
# - We will then find highest index of initial et in the submatrix and substitute the sum value to that region.
# - Finally, we will find the actual index of the ET region and set all others to zero.
# - Then, we will select and sort 6 data values where ET is not zero in descending order.

# %%
# select and sort jet data regions
sorted_jet_data = select_and_sort_jet_data(event_data)
# Out:
# Energy values of Jet after merging
# <style  type="text/css" >
# #T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col0,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col3,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col4,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col6,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col7,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col8,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col9,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col11,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col12,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col13,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col14,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col15,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col16,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row0_col17,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col0,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col1,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col2,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col3,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col4,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col5,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col6,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col8,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col10,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col11,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col13,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col14,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row1_col17,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col0,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col1,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col2,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col3,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col4,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col6,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col7,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col8,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col9,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col11,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col12,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col14,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col15,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col16,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row2_col17,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col0,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col2,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col4,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col5,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col6,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col8,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col10,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col11,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col12,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col13,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col15,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row3_col17,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col1,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col2,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col4,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col7,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col8,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col10,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col12,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col14,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col15,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row4_col17,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col0,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col1,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col2,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col3,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col4,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col5,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col6,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col7,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col8,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col9,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col10,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col11,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col12,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col13,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col15,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_col16,#T_48f9ad31_a9cf_11eb_b533_701ce7ac6322row5_c ...

# %%
sorted_jet_data
# Out:
#      event  eta  phi        et  position  electron  tau
# 49       1    2   13  96.30130         4         1    1
# 218      1   12    2  55.64794         3         0    0
# 244      1   13   10  48.95422        12         0    1
# 164      1    9    2  48.60560         7         0    0
# 63       1    3    9  48.49780        15         1    1
# 168      1    9    6  47.58320         8         0    1
